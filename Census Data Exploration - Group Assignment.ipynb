# %% [markdown]
# # Importing and inspecting HPI data

# %%
import pandas as pd

# %%
# For this project, we are looking at healthy places index and census data
# For the healthy places index, we will look at park access and tree canopy
# For census data, we will look at household income in the past 12 months and poverty level

# %%
HPI = pd.read_csv('data/HPI2_master.csv')
df = pd.read_csv('data/LB_income_poverty.csv')

# %%
HPI.shape
# Out:
# (8057, 91)

# %%
HPI.head()
# Out:
#    CensusTract  pop2010  pct2010gq     City      ZIP  County_FIPS County_Name  \
# 0   6001400100     2937        0.1  Oakland  94704.0         6001     Alameda
# 1   6001400200     1974        3.5  Oakland  94618.0         6001     Alameda
# 2   6001400300     4865        0.8  Oakland  94618.0         6001     Alameda
# 3   6001400400     3703        0.9  Oakland  94609.0         6001     Alameda
# 4   6001400500     3517        3.6  Oakland  94609.0         6001     Alameda
#
#     UrbanType  hpi2score  hpi2_pctile_pos  ...  LEB_pctile  white_pct  \
# 0  urban_area   1.182028        99.114590  ...   96.663673  70.752469
# 1  urban_area   1.325874        99.704863  ...   96.612344  78.318136
# 2  urban_area   0.925666        95.932247  ...   95.136661  66.927030
# 3  urban_area   1.117603        98.537149  ...   68.959322  65.460437
# 4  urban_area   0.562799        83.318363  ...   38.855383  50.554450
#
#    black_pct  asian_pct  latino_pct  multiple_pct  NativeAm_pct  \
# ...

# %%
# We'd like to see the entire data set for a row so lets expand

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
HPI.sample()
# Out:
#       CensusTract  pop2010  pct2010gq City      ZIP  County_FIPS  County_Name  \
# 3426   6037920012     1072        0.0  NaN  91390.0         6037  Los Angeles
#
#      UrbanType  hpi2score  hpi2_pctile_pos  hpi2_pctile_neg hpi_top25pct  \
# 3426     rural        NaN              NaN              NaN          NaN
#
#       quintiles  quartiles  economic  economic_pctile  education  \
# 3426        NaN        NaN       NaN              NaN        NaN
#
#       education_pctile  housing  houseing_pctile  healthcareaccess  \
# 3426               NaN      NaN              NaN               NaN
#
#       healthcareaccess_pctile  neighborhood  neighborhood_pctile  pollution  \
# 3426                      NaN           NaN                  NaN        NaN
#
#       pollution_pctile  transportation  transportation_pctile  social  \
# 3426               NaN             NaN                    NaN     NaN
#
#       social_pctile  insured  insured_pctile  uncrowded  uncrowded_pctile  \
# ...

# %% [markdown]
# # Determining data types

# %%
HPI.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8057 entries, 0 to 8056
# Data columns (total 91 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CensusTract              8057 non-null   int64
#  1   pop2010                  8057 non-null   int64
#  2   pct2010gq                8024 non-null   float64
#  3   City                     6972 non-null   object
#  4   ZIP                      8035 non-null   float64
#  5   County_FIPS              8057 non-null   int64
#  6   County_Name              8057 non-null   object
#  7   UrbanType                8057 non-null   object
#  8   hpi2score                7793 non-null   float64
#  9   hpi2_pctile_pos          7793 non-null   float64
#  10  hpi2_pctile_neg          7793 non-null   float64
#  11  hpi_top25pct             7793 non-null   object
#  12  quintiles                7793 non-null   float64
#  13  quartiles                7793 non-null   float64
# ...

# %%
HPI.CensusTract.head()
HPI.County_FIPS.head()
# Out:
# 0    6001
# 1    6001
# 2    6001
# 3    6001
# 4    6001
# Name: County_FIPS, dtype: int64

# %%
# We need to get the leading "0" back in the FIPS code

# %%
HPI = pd.read_csv(
    'data/HPI2_master.csv',
    dtype=
    {
        'CensusTract':str,
        'County_FIPS':str,
    }
)

# %%
HPI.head()
# Out:
#    CensusTract  pop2010  pct2010gq     City      ZIP County_FIPS County_Name  \
# 0  06001400100     2937        0.1  Oakland  94704.0       06001     Alameda
# 1  06001400200     1974        3.5  Oakland  94618.0       06001     Alameda
# 2  06001400300     4865        0.8  Oakland  94618.0       06001     Alameda
# 3  06001400400     3703        0.9  Oakland  94609.0       06001     Alameda
# 4  06001400500     3517        3.6  Oakland  94609.0       06001     Alameda
#
#     UrbanType  hpi2score  hpi2_pctile_pos  hpi2_pctile_neg hpi_top25pct  \
# 0  urban_area   1.182028        99.114590         0.885410          Yes
# 1  urban_area   1.325874        99.704863         0.295137          Yes
# 2  urban_area   0.925666        95.932247         4.067753          Yes
# 3  urban_area   1.117603        98.537149         1.462851          Yes
# 4  urban_area   0.562799        83.318363        16.681637          Yes
#
#    quintiles  quartiles  economic  economic_pctile  education  \
# ...

# %%
# Leading "0" is back but lets ensure that CountyFIPS is the correct data type

# %%
HPI.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8057 entries, 0 to 8056
# Data columns (total 91 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CensusTract              8057 non-null   object
#  1   pop2010                  8057 non-null   int64
#  2   pct2010gq                8024 non-null   float64
#  3   City                     6972 non-null   object
#  4   ZIP                      8035 non-null   float64
#  5   County_FIPS              8057 non-null   object
#  6   County_Name              8057 non-null   object
#  7   UrbanType                8057 non-null   object
#  8   hpi2score                7793 non-null   float64
#  9   hpi2_pctile_pos          7793 non-null   float64
#  10  hpi2_pctile_neg          7793 non-null   float64
#  11  hpi_top25pct             7793 non-null   object
#  12  quintiles                7793 non-null   float64
#  13  quartiles                7793 non-null   float64
# ...

# %%
# And it is since the type is "object"

# %% [markdown]
# # Dropping/ deleting null columns

# %%
HPI = HPI.drop('version', axis=1)
HPI.head()
# Out:
#    CensusTract  pop2010  pct2010gq     City      ZIP County_FIPS County_Name  \
# 0  06001400100     2937        0.1  Oakland  94704.0       06001     Alameda
# 1  06001400200     1974        3.5  Oakland  94618.0       06001     Alameda
# 2  06001400300     4865        0.8  Oakland  94618.0       06001     Alameda
# 3  06001400400     3703        0.9  Oakland  94609.0       06001     Alameda
# 4  06001400500     3517        3.6  Oakland  94609.0       06001     Alameda
#
#     UrbanType  hpi2score  hpi2_pctile_pos  hpi2_pctile_neg hpi_top25pct  \
# 0  urban_area   1.182028        99.114590         0.885410          Yes
# 1  urban_area   1.325874        99.704863         0.295137          Yes
# 2  urban_area   0.925666        95.932247         4.067753          Yes
# 3  urban_area   1.117603        98.537149         1.462851          Yes
# 4  urban_area   0.562799        83.318363        16.681637          Yes
#
#    quintiles  quartiles  economic  economic_pctile  education  \
# ...

# %% [markdown]
# # Renaming columns using .txt file

# %%
columns = list(HPI)
columns
# Out:
# ['CensusTract',
#  'pop2010',
#  'pct2010gq',
#  'City',
#  'ZIP',
#  'County_FIPS',
#  'County_Name',
#  'UrbanType',
#  'hpi2score',
#  'hpi2_pctile_pos',
#  'hpi2_pctile_neg',
#  'hpi_top25pct',
#  'quintiles',
#  'quartiles',
#  'economic',
#  'economic_pctile',
#  'education',
#  'education_pctile',
#  'housing',
#  'houseing_pctile',
#  'healthcareaccess',
#  'healthcareaccess_pctile',
#  'neighborhood',
#  'neighborhood_pctile',
#  'pollution',
#  'pollution_pctile',
#  'transportation',
#  'transportation_pctile',
#  'social',
#  'social_pctile',
#  'insured',
#  'insured_pctile',
#  'uncrowded',
#  'uncrowded_pctile',
#  'homeownership',
#  'homeownership_pctile',
#  'automobile',
#  'automobile_pctile',
#  'commute',
#  'commute_pctile',
#  'inpreschool',
#  'inpreschool_pctile',
#  'inhighschool',
#  'inhighschool_pctile',
#  'bachelorsed',
#  'bachelorsed_pctile',
#  'employed',
#  'employed_pctile',
#  'abovepoverty',
#  'abovepoverty_pctile',
#  'income',
# ...

# %%
HPI.columns = ['FIPS',
 'pop2010',
 'pct2010gq',
 'City',
 'ZIP',
 'County_FIPS',
 'County_Name',
 'UrbanType',
 'HPI_score',
 'HPI_pctile_pos',
 'HPI_pctile_neg',
 'HPI_top25pct',
 'quintiles',
 'quartiles',
 'economic',
 'economic_pctile',
 'education',
 'education_pctile',
 'housing',
 'houseing_pctile',
 'healthcareaccess',
 'healthcareaccess_pctile',
 'neighborhood',
 'neighborhood_pctile',
 'pollution',
 'pollution_pctile',
 'transportation',
 'transportation_pctile',
 'social',
 'social_pctile',
 'insured',
 'insured_pctile',
 'uncrowded',
 'uncrowded_pctile',
 'homeownership',
 'homeownership_pctile',
 'automobile',
 'automobile_pctile',
 'commute',
 'commute_pctile',
 'inpreschool',
 'inpreschool_pctile',
 'inhighschool',
 'inhighschool_pctile',
 'bachelorsed',
 'bachelorsed_pctile',
 'employed',
 'employed_pctile',
 'abovepoverty',
 'abovepoverty_pctile',
 'income',
 'income_pctile',
 'retail',
 'retail_pctile',
 'parkaccess',
 'parkaccess_pctile',
 'treecanopy',
 'treecanopy_pctile',
 'alcoffsale',
 'alcoffsale_pctile',
 'voting',
 'voting_pctile',
 'ownsevere',
 'ownsevere_pctile',
 'rentsevere',
 'rentsevere_pctile',
 'houserepair',
 'houserepair_pctile',
 'twoparents',
 'twoparents_pctile',
 'supermkts',
 'supermkts_pctile',
 'ozone',
 'ozone_pctile',
 'pm25',
 'pm25_pctile',
 'dieselpm',
 'dieselpm_pctile',
 'h20contam',
 'h20contam_pctile',
 'LEB',
 'LEB_pctile',
 'white_pct',
 'black_pct',
 'asian_pct',
 'latino_pct',
 'multiple_pct',
 'NativeAm_pct',
 'PacificIsl_pct',
 'other_pct']

# %%
HPI.head ()
# Out:
#           FIPS  pop2010  pct2010gq     City      ZIP County_FIPS County_Name  \
# 0  06001400100     2937        0.1  Oakland  94704.0       06001     Alameda
# 1  06001400200     1974        3.5  Oakland  94618.0       06001     Alameda
# 2  06001400300     4865        0.8  Oakland  94618.0       06001     Alameda
# 3  06001400400     3703        0.9  Oakland  94609.0       06001     Alameda
# 4  06001400500     3517        3.6  Oakland  94609.0       06001     Alameda
#
#     UrbanType  HPI_score  HPI_pctile_pos  HPI_pctile_neg HPI_top25pct  \
# 0  urban_area   1.182028       99.114590        0.885410          Yes
# 1  urban_area   1.325874       99.704863        0.295137          Yes
# 2  urban_area   0.925666       95.932247        4.067753          Yes
# 3  urban_area   1.117603       98.537149        1.462851          Yes
# 4  urban_area   0.562799       83.318363       16.681637          Yes
#
#    quintiles  quartiles  economic  economic_pctile  education  \
# ...

# %%
# They are re-named!

# %% [markdown]
# # Inspecting Census data

# %%
#now that HPI is ready/clean, we will move onto our census data which we named here as df
#first, checking the size of our dataset

# %%
df.shape
# Out:
# (113, 91)

# %%
df.head()
# Out:
#      Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  6037544001  14000US06037544001  Census Tract 5440.01
# 1  6037544002  14000US06037544002  Census Tract 5440.02
# 2  6037555202  14000US06037555202  Census Tract 5552.02
# 3  6037570100  14000US06037570100     Census Tract 5701
# 4  6037570202  14000US06037570202  Census Tract 5702.02
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 5440.01, Los Angeles County, Cali...         ca         140
# 1  Census Tract 5440.02, Los Angeles County, Cali...         ca         140
# 2  Census Tract 5552.02, Los Angeles County, Cali...         ca         140
# 3  Census Tract 5701, Los Angeles County, California         ca         140
# 4  Census Tract 5702.02, Los Angeles County, Cali...         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0            0      ACSSF          5591     NaN         NaN           NaN
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.sample ()
# Out:
#       Geo_FIPS           Geo_GEOID           Geo_NAME  \
# 82  6037576200  14000US06037576200  Census Tract 5762
#
#                                             Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 82  Census Tract 5762, Los Angeles County, California         ca         140
#
#     Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 82            0      ACSSF          5782     NaN         NaN           NaN
#
#     Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_PLACESE  \
# 82          NaN          6          37         NaN        NaN          NaN
#
#     Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  \
# 82     576200         NaN         NaN         NaN           NaN          NaN
#
#     Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  \
# 82         NaN       NaN       NaN       NaN      NaN         NaN       NaN
#
#     Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  Geo_UA  Geo_UACP  \
# ...

# %% [markdown]
# # Determining data types

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 91 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           113 non-null    int64
#  1   Geo_GEOID          113 non-null    object
#  2   Geo_NAME           113 non-null    object
#  3   Geo_QName          113 non-null    object
#  4   Geo_STUSAB         113 non-null    object
#  5   Geo_SUMLEV         113 non-null    int64
#  6   Geo_GEOCOMP        113 non-null    int64
#  7   Geo_FILEID         113 non-null    object
#  8   Geo_LOGRECNO       113 non-null    int64
#  9   Geo_US             0 non-null      float64
#  10  Geo_REGION         0 non-null      float64
#  11  Geo_DIVISION       0 non-null      float64
#  12  Geo_STATECE        0 non-null      float64
#  13  Geo_STATE          113 non-null    int64
#  14  Geo_COUNTY         113 non-null    int64
#  15  Geo_COUSUB         0 non-null      float64
# ...

# %%
df.Geo_FIPS.head()
# Out:
# 0    6037544001
# 1    6037544002
# 2    6037555202
# 3    6037570100
# 4    6037570202
# Name: Geo_FIPS, dtype: int64

# %%
df.Geo_STATE.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: Geo_STATE, dtype: int64

# %%
df.Geo_COUNTY.head()
# Out:
# 0    37
# 1    37
# 2    37
# 3    37
# 4    37
# Name: Geo_COUNTY, dtype: int64

# %%
# The leading "0" is missing from these FIPS codes so we will add back in

# %%
df = pd.read_csv(
    'data/LB_income_poverty.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY':str
    }
)

# %%
df.head()
# Out:
#       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  06037544001  14000US06037544001  Census Tract 5440.01
# 1  06037544002  14000US06037544002  Census Tract 5440.02
# 2  06037555202  14000US06037555202  Census Tract 5552.02
# 3  06037570100  14000US06037570100     Census Tract 5701
# 4  06037570202  14000US06037570202  Census Tract 5702.02
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 5440.01, Los Angeles County, Cali...         ca         140
# 1  Census Tract 5440.02, Los Angeles County, Cali...         ca         140
# 2  Census Tract 5552.02, Los Angeles County, Cali...         ca         140
# 3  Census Tract 5701, Los Angeles County, California         ca         140
# 4  Census Tract 5702.02, Los Angeles County, Cali...         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0            0      ACSSF          5591     NaN         NaN           NaN
# ...

# %%
# Leading "0" is back!

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 91 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           113 non-null    object
#  1   Geo_GEOID          113 non-null    object
#  2   Geo_NAME           113 non-null    object
#  3   Geo_QName          113 non-null    object
#  4   Geo_STUSAB         113 non-null    object
#  5   Geo_SUMLEV         113 non-null    int64
#  6   Geo_GEOCOMP        113 non-null    int64
#  7   Geo_FILEID         113 non-null    object
#  8   Geo_LOGRECNO       113 non-null    int64
#  9   Geo_US             0 non-null      float64
#  10  Geo_REGION         0 non-null      float64
#  11  Geo_DIVISION       0 non-null      float64
#  12  Geo_STATECE        0 non-null      float64
#  13  Geo_STATE          113 non-null    object
#  14  Geo_COUNTY         113 non-null    object
#  15  Geo_COUSUB         0 non-null      float64
# ...

# %%
# Add we can confirm that the FIPS columns are the correct data type now ("object")

# %% [markdown]
# # Deleting/ Dropping null columns

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1']

# %%
df = df.dropna(axis=1,how="all")

# %%
columns_to_drop = ['Geo_GEOID','Geo_STUSAB','Geo_SUMLEV','Geo_GEOCOMP','Geo_FILEID','Geo_LOGRECNO']

# %%
df = df.drop(columns_to_drop,axis=1)
df.head()
# Out:
#       Geo_FIPS              Geo_NAME  \
# 0  06037544001  Census Tract 5440.01
# 1  06037544002  Census Tract 5440.02
# 2  06037555202  Census Tract 5552.02
# 3  06037570100     Census Tract 5701
# 4  06037570202  Census Tract 5702.02
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 5440.01, Los Angeles County, Cali...        06        037
# 1  Census Tract 5440.02, Los Angeles County, Cali...        06        037
# 2  Census Tract 5552.02, Los Angeles County, Cali...        06        037
# 3  Census Tract 5701, Los Angeles County, California        06        037
# 4  Census Tract 5702.02, Los Angeles County, Cali...        06        037
#
#    Geo_TRACT  SE_A14002_001  SE_A14002_002  SE_A14002_003  SE_A14002_004  \
# 0     544001           1143             14             20             17
# 1     544002            813             13             12             46
# ...

# %%
# all unnecessary columns are now dropped

# %% [markdown]
# # Renamning columns

# %%
columns_1 = list(df)
columns_1
# Out:
# ['Geo_FIPS',
#  'Geo_NAME',
#  'Geo_QName',
#  'Geo_STATE',
#  'Geo_COUNTY',
#  'Geo_TRACT',
#  'SE_A14002_001',
#  'SE_A14002_002',
#  'SE_A14002_003',
#  'SE_A14002_004',
#  'SE_A14002_005',
#  'SE_A14002_006',
#  'SE_A14002_007',
#  'SE_A14002_008',
#  'SE_A14002_009',
#  'SE_A14002_010',
#  'SE_A14002_011',
#  'SE_A14002_012',
#  'PCT_SE_A14002_002',
#  'PCT_SE_A14002_003',
#  'PCT_SE_A14002_004',
#  'PCT_SE_A14002_005',
#  'PCT_SE_A14002_006',
#  'PCT_SE_A14002_007',
#  'PCT_SE_A14002_008',
#  'PCT_SE_A14002_009',
#  'PCT_SE_A14002_010',
#  'PCT_SE_A14002_011',
#  'PCT_SE_A14002_012',
#  'SE_A13004_001',
#  'SE_A13004_002',
#  'SE_A13004_003',
#  'SE_A13004_004',
#  'SE_A13004_005',
#  'SE_A13004_006',
#  'SE_A13004_007',
#  'PCT_SE_A13004_002',
#  'PCT_SE_A13004_003',
#  'PCT_SE_A13004_004',
#  'PCT_SE_A13004_005',
#  'PCT_SE_A13004_006',
#  'PCT_SE_A13004_007']

# %%
df.columns = ['FIPS',
 'Geo_NAME',
 'Geo_QName',
 'Geo_STATE',
 'Geo_COUNTY',
 'Geo_TRACT',
 'Occupied_HousingUnits',
 'Less_than_5K',
 '5K_to_9999',
 '10K_to_14999',
 '15K_to_19999',
 '20K_to_24999',
 '25K_to_34999',
 '35K_to_49999',
 '50K_to_74999',
 '75K_to_99999',
 '100K_to_149999',
 '150K_or_more',
 'PCT_less_than_5K',
 'PCT_5K_to_9999',
 'PCT_10K_to_14999',
 'PCT_15K_to_19999',
 'PCT_20K_to_24999',
 'PCT_25K_to_34999',
 'PCT_35K_to_49999',
 'PCT_50K_to_74999',
 'PCT_75K_to_99999',
 'PCT_100K_to_149999',
 'PCT_150K_or_more',
 'Pop_pov',
 'Pov_under_50',
 'Pov_50_to_74',
 'Pov_75_to_99',
 'Pov_100_to_149',
 'Pov_150_to_199',
 'Pov_200_or_more',
 'PCT_Pov_under_50',
 'PCT_Pov_50_to_74',
 'PCT_Pov_75_to_99',
 'PCT_Pov_100_to_149',
 'PCT_Pov_150_to_199',
 'PCT_Pov_200_or_more']

# %%
df.head ()
# Out:
#           FIPS              Geo_NAME  \
# 0  06037544001  Census Tract 5440.01
# 1  06037544002  Census Tract 5440.02
# 2  06037555202  Census Tract 5552.02
# 3  06037570100     Census Tract 5701
# 4  06037570202  Census Tract 5702.02
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 5440.01, Los Angeles County, Cali...        06        037
# 1  Census Tract 5440.02, Los Angeles County, Cali...        06        037
# 2  Census Tract 5552.02, Los Angeles County, Cali...        06        037
# 3  Census Tract 5701, Los Angeles County, California        06        037
# 4  Census Tract 5702.02, Los Angeles County, Cali...        06        037
#
#    Geo_TRACT  Occupied_HousingUnits  Less_than_5K  5K_to_9999  10K_to_14999  \
# 0     544001                   1143            14          20            17
# 1     544002                    813            13          12            46
# ...

# %%
# they have been successfully renamed

# %% [markdown]
# # Merging data sets

# %%
#now that both df and HPI are ready, we will merge them and match them using the 'FIPS' column/code in each database
#calling the merged dataset 'HPI_cen'

# %%
HPI_cen = df.merge(HPI,on="FIPS")

# %%
HPI_cen.head()
# Out:
#           FIPS              Geo_NAME  \
# 0  06037544001  Census Tract 5440.01
# 1  06037544002  Census Tract 5440.02
# 2  06037555202  Census Tract 5552.02
# 3  06037570100     Census Tract 5701
# 4  06037570202  Census Tract 5702.02
#
#                                            Geo_QName Geo_STATE Geo_COUNTY  \
# 0  Census Tract 5440.01, Los Angeles County, Cali...        06        037
# 1  Census Tract 5440.02, Los Angeles County, Cali...        06        037
# 2  Census Tract 5552.02, Los Angeles County, Cali...        06        037
# 3  Census Tract 5701, Los Angeles County, California        06        037
# 4  Census Tract 5702.02, Los Angeles County, Cali...        06        037
#
#    Geo_TRACT  Occupied_HousingUnits  Less_than_5K  5K_to_9999  10K_to_14999  \
# 0     544001                   1143            14          20            17
# 1     544002                    813            13          12            46
# ...

# %% [markdown]
# # Sorting data and making charts

# %%
df_sorted = df.sort_values(by='Less_than_5K',ascending = False)

# %%
df_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='Less_than_5K',
                           title='Top 10 Census Tracts with Lowest Household Income in Long Beach')

# %% [markdown]
# **Chart 1: Top 10 Census Tracts with lowest households income in Long Beach**

# %%
df_sorted[['Geo_NAME','150K_or_more']].head(10)
# Out:
#                  Geo_NAME  150K_or_more
# 64   Census Tract 5749.02           179
# 80   Census Tract 5759.02           246
# 18      Census Tract 5712           719
# 82      Census Tract 5762           168
# 96   Census Tract 5769.01            49
# 7    Census Tract 5703.01            53
# 107  Census Tract 5776.03          1201
# 97   Census Tract 5769.03            61
# 62      Census Tract 5748           424
# 104  Census Tract 5775.01           698

# %%
df_sorted = df.sort_values(by='150K_or_more',ascending = False)

# %%
df_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='150K_or_more',
                           title='Top 10 Census Tracts with Highest Household Income in Long Beach')

# %% [markdown]
# **Chart 2: Top 10 census tracts in Long Beach with highest household income**

# %%
df_sorted[['Pov_under_50']].head(10)
# Out:
#      Pov_under_50
# 107           543
# 48            225
# 52            275
# 58            193
# 18            455
# 104           272
# 28            249
# 101           340
# 27             89
# 81            172

# %%
df_sorted = df.sort_values(by='Pov_under_50',ascending = False)

# %%
df_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='Pov_under_50',
                           title='Top 10 Census Tracts in Long Beach with Poverty under 50 percent')

# %% [markdown]
# **Chart 3: Top 10 census tracts in Long Beach with poverty under 50 percent**

# %%
df_sorted[['Pov_200_or_more']].head(10)
# Out:
#     Pov_200_or_more
# 64             2213
# 77             1560
# 96             2110
# 13             4064
# 87             1731
# 82             2312
# 71             1846
# 72             1319
# 89             2031
# 7              3234

# %%
df_sorted = df.sort_values(by='Pov_200_or_more',ascending = False)

# %%
df_sorted.head(10).plot.bar(x='Geo_NAME',
                            y='Pov_200_or_more',
                           title='Top 10 Census Tracts in Long Beach with Poverty at 200 percent or more')

# %% [markdown]
# **Chart 4: Top 10 census tracts in long beach with poverty at 200 percent or more**

# %%
HPI_sorted = HPI.sort_values(by='treecanopy_pctile',ascending = False)

# %%
HPI_sorted [['treecanopy_pctile']].head(10)
# Out:
#       treecanopy_pctile
# 0             97.420762
# 4251          15.090466
# 4221          21.416656
# 4222          20.428590
# 4225          16.514821
# 4226          20.941871
# 4227          15.834723
# 4232          15.128962
# 4234          26.305659
# 4235          20.171949

# %%
HPI_sorted = HPI.sort_values(by='parkaccess_pctile',ascending = False)

# %%
HPI_sorted [['parkaccess_pctile']].head(20)
# Out:
#       parkaccess_pctile
# 0             81.355062
# 4251          81.355062
# 4221          81.355062
# 4222          81.355062
# 4225          81.355062
# 4226          81.355062
# 4227          81.355062
# 4232          81.355062
# 4234          81.355062
# 4235          81.355062
# 4238          81.355062
# 4241          81.355062
# 4242          81.355062
# 4243          81.355062
# 4248          81.355062
# 4249          81.355062
# 4253          81.355062
# 4218          81.355062
# 4256          81.355062
# 4269          81.355062

# %%
#now that our data is merged, we will add a geomtry track to it so we can create a map 
#to create a map, we need to import geopandas

# %% [markdown]
# # Map exploration

# %%
import geopandas as gpd

# %%
lacounty=gpd.read_file('../../data/la_tracts.geojson')
lacounty.head()
# Out:
#                   kind  external_id         name  \
# 0  Census Tract (2012)  06037101110  06037101110
# 1  Census Tract (2012)  06037101122  06037101122
# 2  Census Tract (2012)  06037101210  06037101210
# 3  Census Tract (2012)  06037101220  06037101220
# 4  Census Tract (2012)  06037101300  06037101300
#
#                             slug                                    set  \
# 0  06037101110-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 1  06037101122-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 2  06037101210-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 3  06037101220-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
# 4  06037101300-census-tract-2012  /1.0/boundary-set/census-tracts-2012/
#
#                                             metadata  \
# 0  {'INTPTLAT': '+34.2594737', 'NAME': '1011.10',...
# 1  {'INTPTLAT': '+34.2677213', 'NAME': '1011.22',...
# 2  {'INTPTLAT': '+34.2529724', 'NAME': '1012.10',...
# ...

# %%
lacounty.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kind          2346 non-null   object
#  1   external_id   2346 non-null   object
#  2   name          2346 non-null   object
#  3   slug          2346 non-null   object
#  4   set           2346 non-null   object
#  5   metadata      2346 non-null   object
#  6   resource_uri  2346 non-null   object
#  7   geometry      2346 non-null   geometry
# dtypes: geometry(1), object(7)
# memory usage: 146.8+ KB

# %%
lacounty = lacounty[['name','geometry']]
lacounty.head()
# Out:
#           name                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
#renaming columns

# %%
lacounty.columns = ['FIPS','geometry']
lacounty.head()
# Out:
#           FIPS                                           geometry
# 0  06037101110  MULTIPOLYGON (((-118.30229 34.25870, -118.3007...
# 1  06037101122  MULTIPOLYGON (((-118.30333 34.27354, -118.3031...
# 2  06037101210  MULTIPOLYGON (((-118.29945 34.25598, -118.2859...
# 3  06037101220  MULTIPOLYGON (((-118.28592 34.24896, -118.2859...
# 4  06037101300  MULTIPOLYGON (((-118.27247 34.23253, -118.2719...

# %%
lacounty.plot(figsize=(12,10))

# %%
#now, we will merge the 'HPI_cen' with the 'lacounty' data by matching the FIPS code/column
#we will call this new merged dataset 'data'

# %%
data = lacounty.merge(HPI_cen,on="FIPS")

# %%
data.head ()
# Out:
#           FIPS                                           geometry  \
# 0  06037544001  MULTIPOLYGON (((-118.22542 33.83258, -118.2202...
# 1  06037544002  MULTIPOLYGON (((-118.22661 33.82948, -118.2255...
# 2  06037555202  MULTIPOLYGON (((-118.08157 33.82029, -118.0815...
# 3  06037570100  MULTIPOLYGON (((-118.15989 33.86108, -118.1599...
# 4  06037570202  MULTIPOLYGON (((-118.18610 33.87574, -118.1859...
#
#                Geo_NAME                                          Geo_QName  \
# 0  Census Tract 5440.01  Census Tract 5440.01, Los Angeles County, Cali...
# 1  Census Tract 5440.02  Census Tract 5440.02, Los Angeles County, Cali...
# 2  Census Tract 5552.02  Census Tract 5552.02, Los Angeles County, Cali...
# 3     Census Tract 5701  Census Tract 5701, Los Angeles County, California
# 4  Census Tract 5702.02  Census Tract 5702.02, Los Angeles County, Cali...
#
#   Geo_STATE Geo_COUNTY  Geo_TRACT  Occupied_HousingUnits  Less_than_5K  \
# ...

# %%
data.shape
# Out:
# (113, 132)

# %%
data.plot(figsize=(12,10),
                 column='PCT_less_than_5K',
                 legend=True, 
                 scheme='equal_interval')

# %% [markdown]
# **Map 1: Percentile of households with an income less than $5,0000 in the past 12 months**

# %%
data.plot(figsize=(12,10),
                 column='PCT_150K_or_more',
                 legend=True, 
                 scheme='equal_interval')

# %% [markdown]
# **Map 2: Percentile of Households with an income of $150,000 or more in the past 12 months**

# %%
#percentile of people under 50% of poverty level
data.plot(figsize=(12,10),
                 column='PCT_Pov_under_50',
                 legend=True, 
                 scheme='equal_interval')

# %% [markdown]
# **Map 3: Percentile of households under 50% of the poverty level**

# %%
data.plot(figsize=(12,10),
                 column='PCT_Pov_200_or_more',
                 legend=True, 
                 scheme='equal_interval')

# %% [markdown]
# **Map 4: Percentile of households at 200% or more of the poverty level**

# %%
data.plot(figsize=(12,10),
                 column='HPI_score',
                 legend=True, 
                 scheme='equal_interval')

# %% [markdown]
# **Map 5: HPI scores**

# %%
data.plot(figsize=(12,10),
                 column='parkaccess',
                 legend=True, 
                 scheme='equal_interval')

# %% [markdown]
# **Map 6: Park access**

# %%
data.plot(figsize=(12,10),
                 column='treecanopy',
                 legend=True, 
                 scheme='natural_breaks')

# %% [markdown]
# **Map 7: Tree Canopy**

# %% [markdown]
# **The members of this group are: Wendy Miranda and Sasha Ragland.**
# Both Wendy and Sasha imported and inspected the HPI and census data.
# Sasha sorted data and created the charts.
# Wendy carried out the map exploration.
